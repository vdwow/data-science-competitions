# %%
import numpy as np
import pandas as pd
import seaborn as sb

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
train = pd.read_csv('/kaggle/input/tabular-playground-series-jan-2021/train.csv')
test = pd.read_csv('/kaggle/input/tabular-playground-series-jan-2021/test.csv')

# %%
train.head()

# %%
sb.heatmap(train.corr())

# %% [markdown]
# Lasso, Ridge, RF, SVM, KNN

# %%
from sklearn import linear_model, model_selection, tree, metrics, neural_network, ensemble
from xgboost import XGBRegressor

# %%
models = [linear_model.LinearRegression(), linear_model.Lasso(), linear_model.Ridge(), linear_model.BayesianRidge(),
          tree.DecisionTreeRegressor(), tree.ExtraTreeRegressor(),
          ensemble.AdaBoostRegressor(), ensemble.GradientBoostingRegressor(),
         XGBRegressor()]

# %%
features = train.drop(['id', 'target'], axis = 1).columns.to_list()

X_train, X_test, y_train, y_test = model_selection.train_test_split(train[features], train['target'], random_state = 42)

# %%
# regressors_comparison = pd.DataFrame()
# #cv_split = model_selection.ShuffleSplit(n_splits = 3, test_size = .4, train_size = .6, random_state = 42 )

# for model in models:

#     model.fit(X_train, y_train)
    
#     y_pred = model.predict(X_test)
    
#     regressors_comparison = regressors_comparison.append({'model':model.__class__.__name__,
#                                                         'rmse': metrics.mean_squared_error(y_test, y_pred)**(0.5)},
#                                    ignore_index = True)
    
#     print(str(model) + ' is trained !')

# %%
regressors_comparison

# %%
model

# %%
test['target'] = model.predict(test.drop('id', axis = 1))
submission = test[['id','target']]
submission.to_csv('submission.csv', index=False)
